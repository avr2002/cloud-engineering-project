# %% [markdown]
# # OpenAI SDK Playground
#
# > 📌 **Note:** this notebook does not render well in GitHub. View it in your editor, e.g. VS Code to see the generated content.
#
# - install the required libraries by running `pip install -r requirements.txt`
# - create a `.env` file following the pattern in `.env.example`
#   - be sure `*.env` is in your `.gitignore` file
#   - to do this, you will need an OpenAI API Key.
#
# You'll have to sign up for OpenAI first. At one point they gave some initial free credits. If you do not see those in your account, then the minimum you can pay them is $5 USD. Watch your spend, but $5 USD should be plenty to follow along with the course.. https://platform.openai.com/api-keys
#
# ## Guide for creating an API key
#
# You need to sign up first. Once you do that, this video shows how to get an API key. ([video link](https://www.youtube.com/embed/gBSh9JI28UQ?si=1bXff7lMU2eusU-S), in case the embed does not render)
#
# <iframe width="560" height="315" src="https://www.youtube.com/embed/gBSh9JI28UQ?si=1bXff7lMU2eusU-S" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
#
# **Recommended key settings:**
#
# <img src="../../assets/openai-key-settings.png" width="400px">

# %% [markdown]
# ## Imports

# %%
# imports - be sure to install the requirements.txt and create a .env file

from pathlib import Path

import IPython
from dotenv import load_dotenv
from openai import AsyncOpenAI
from openai.types.chat import ChatCompletion
from rich import print

# %% [markdown]
# ## Load environment variables from `.env`
#
# The OpenAI Client will implicitly use the OpenAI key loaded from this file
# because it the env var uses the standard name `OPENAI_API_KEY`.

# %%
# Constants

load_dotenv()  # read and export env vars in .env -- the OpenAI client
# Out:
# True

# %% [markdown]
# ## Text Generation
#
# OpenAPI SDK docs on text generation [here](https://platform.openai.com/docs/guides/text-generation/chat-completions-api).

# %%
system_prompt = "You are an autocompletion tool that produces text files given constraints."
prompt = "toml file representing a setuptools python package"

client = AsyncOpenAI()

response: ChatCompletion = await client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": prompt},
    ],
    max_tokens=100,  # avoid burning your credits
    n=2,  # number of responses
)

print(response)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[5], line 6
#       2 prompt = "toml file representing a setuptools python package"
#       4 client = AsyncOpenAI()
# ----> 6 response: ChatCompletion = await client.chat.completions.create(
#       7     model="gpt-3.5-turbo",
#       8     messages=[
#       9         {"role": "system", "content": system_prompt},
#      10         {"role": "user", "content": prompt},
#      11     ],
#      12     max_tokens=100,  # avoid burning your credits
#      13     n=2,  # number of responses
#      14 )
#      16 print(response)
#
# File ~/repos/cloud-engineering-project/.venv/lib/python3.11/site-packages/openai/resources/chat/completions.py:1289, in AsyncCompletions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, parallel_tool_calls, presence_penalty, response_format, seed, service_tier, stop, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#    1255 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1256 async def create(
#    1257     self,
#    (...)
#    1287     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#    1288 ) -> ChatCompletion | AsyncStream[ChatCompletionChunk]:
# -> 1289     return await self._post(
#    1290         "/chat/completions",
#    1291         body=await async_maybe_transform(
#    1292             {
#    1293                 "messages": messages,
#    1294                 "model": model,
#    1295                 "frequency_penalty": frequency_penalty,
#    1296                 "function_call": function_call,
#    1297                 "functions": functions,
#    1298                 "logit_bias": logit_bias,
#    1299                 "logprobs": logprobs,
#    1300                 "max_tokens": max_tokens,
#    1301                 "n": n,
#    1302                 "parallel_tool_calls": parallel_tool_calls,
#    1303                 "presence_penalty": presence_penalty,
#    1304                 "response_format": response_format,
#    1305                 "seed": seed,
#    1306                 "service_tier": service_tier,
#    1307                 "stop": stop,
#    1308                 "stream": stream,
#    1309                 "stream_options": stream_options,
#    1310                 "temperature": temperature,
#    1311                 "tool_choice": tool_choice,
#    1312                 "tools": tools,
#    1313                 "top_logprobs": top_logprobs,
#    1314                 "top_p": top_p,
#    1315                 "user": user,
#    1316             },
#    1317             completion_create_params.CompletionCreateParams,
#    1318         ),
#    1319         options=make_request_options(
#    1320             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1321         ),
#    1322         cast_to=ChatCompletion,
#    1323         stream=stream or False,
#    1324         stream_cls=AsyncStream[ChatCompletionChunk],
#    1325     )
#
# File ~/repos/cloud-engineering-project/.venv/lib/python3.11/site-packages/openai/_base_client.py:1805, in AsyncAPIClient.post(self, path, cast_to, body, files, options, stream, stream_cls)
#    1791 async def post(
#    1792     self,
#    1793     path: str,
#    (...)
#    1800     stream_cls: type[_AsyncStreamT] | None = None,
#    1801 ) -> ResponseT | _AsyncStreamT:
#    1802     opts = FinalRequestOptions.construct(
#    1803         method="post", url=path, json_data=body, files=await async_to_httpx_files(files), **options
#    1804     )
# -> 1805     return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#
# File ~/repos/cloud-engineering-project/.venv/lib/python3.11/site-packages/openai/_base_client.py:1503, in AsyncAPIClient.request(self, cast_to, options, stream, stream_cls, remaining_retries)
#    1494 async def request(
#    1495     self,
#    1496     cast_to: Type[ResponseT],
#    (...)
#    1501     remaining_retries: Optional[int] = None,
#    1502 ) -> ResponseT | _AsyncStreamT:
# -> 1503     return await self._request(
#    1504         cast_to=cast_to,
#    1505         options=options,
#    1506         stream=stream,
#    1507         stream_cls=stream_cls,
#    1508         remaining_retries=remaining_retries,
#    1509     )
#
# File ~/repos/cloud-engineering-project/.venv/lib/python3.11/site-packages/openai/_base_client.py:1584, in AsyncAPIClient._request(self, cast_to, options, stream, stream_cls, remaining_retries)
#    1582 if retries > 0 and self._should_retry(err.response):
#    1583     await err.response.aclose()
# -> 1584     return await self._retry_request(
#    1585         options,
#    1586         cast_to,
#    1587         retries,
#    1588         err.response.headers,
#    1589         stream=stream,
#    1590         stream_cls=stream_cls,
#    1591     )
#    1593 # If the response is streamed then we need to explicitly read the response
#    1594 # to completion before attempting to access the response text.
#    1595 if not err.response.is_closed:
#
# File ~/repos/cloud-engineering-project/.venv/lib/python3.11/site-packages/openai/_base_client.py:1630, in AsyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1626 log.info("Retrying request to %s in %f seconds", options.url, timeout)
#    1628 await anyio.sleep(timeout)
# -> 1630 return await self._request(
#    1631     options=options,
#    1632     cast_to=cast_to,
#    1633     remaining_retries=remaining,
#    1634     stream=stream,
#    1635     stream_cls=stream_cls,
#    1636 )
#
# File ~/repos/cloud-engineering-project/.venv/lib/python3.11/site-packages/openai/_base_client.py:1584, in AsyncAPIClient._request(self, cast_to, options, stream, stream_cls, remaining_retries)
#    1582 if retries > 0 and self._should_retry(err.response):
#    1583     await err.response.aclose()
# -> 1584     return await self._retry_request(
#    1585         options,
#    1586         cast_to,
#    1587         retries,
#    1588         err.response.headers,
#    1589         stream=stream,
#    1590         stream_cls=stream_cls,
#    1591     )
#    1593 # If the response is streamed then we need to explicitly read the response
#    1594 # to completion before attempting to access the response text.
#    1595 if not err.response.is_closed:
#
# File ~/repos/cloud-engineering-project/.venv/lib/python3.11/site-packages/openai/_base_client.py:1630, in AsyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1626 log.info("Retrying request to %s in %f seconds", options.url, timeout)
#    1628 await anyio.sleep(timeout)
# -> 1630 return await self._request(
#    1631     options=options,
#    1632     cast_to=cast_to,
#    1633     remaining_retries=remaining,
#    1634     stream=stream,
#    1635     stream_cls=stream_cls,
#    1636 )
#
# File ~/repos/cloud-engineering-project/.venv/lib/python3.11/site-packages/openai/_base_client.py:1599, in AsyncAPIClient._request(self, cast_to, options, stream, stream_cls, remaining_retries)
#    1596         await err.response.aread()
#    1598     log.debug("Re-raising status error")
# -> 1599     raise self._make_status_error_from_response(err.response) from None
#    1601 return await self._process_response(
#    1602     cast_to=cast_to,
#    1603     options=options,
#    (...)
#    1606     stream_cls=stream_cls,
#    1607 )
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}

# %% [markdown]
# ## Image Generation
#
# OpenAPI SDK docs on image generation [here](https://platform.openai.com/docs/guides/images/introduction).

# %%
from openai import OpenAI

client = AsyncOpenAI()

image_response = await client.images.generate(
  model="dall-e-3",
  prompt="minecraft steve learning Python and AWS",
  size="1024x1024",
  quality="standard",
  n=1,
)

print(image_response)
# Out:
# ImagesResponse(
#     created=1720680961,
#     data=[
#         Image(
#             b64_json=None,
#             revised_prompt='An image of a blocky character with blue clothing and brown hair, reminiscent of a
# popular sandbox game, sitting in front of a modern computer. The screen of the computer displays Python code and
# AWS interface. The character appears focused, with an open book about Python and AWS on the desk. The room has
# pixelated walls, a window with blocky trees outside, and a torch giving off a warm light.',
#             url='https://oaidalleapiprodscus.blob.core.windows.net/private/org-vrO2RQa2nyCX4A3uBmZDJA6H/user-UChZNi
# zYaIqin4eVHFryXCTx/img-fSuJEsQ3zhxWwsdswSF3pvDe.png?st=2024-07-11T05%3A56%3A01Z&se=2024-07-11T07%3A56%3A01Z&sp=r&sv
# =2023-11-03&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a81
# 4-9c849652bcb3&skt=2024-07-11T02%3A18%3A02Z&ske=2024-07-12T02%3A18%3A02Z&sks=b&skv=2023-11-03&sig=RdxR6g687hwg7R4GJ
# IbqW6Exh9rwNJZE6r%2B51Viu4HA%3D'
#         )
#     ]
# )

# %%
print(image_response)
# Out:
# ImagesResponse(
#     created=1720680961,
#     data=[
#         Image(
#             b64_json=None,
#             revised_prompt='An image of a blocky character with blue clothing and brown hair, reminiscent of a
# popular sandbox game, sitting in front of a modern computer. The screen of the computer displays Python code and
# AWS interface. The character appears focused, with an open book about Python and AWS on the desk. The room has
# pixelated walls, a window with blocky trees outside, and a torch giving off a warm light.',
#             url='https://oaidalleapiprodscus.blob.core.windows.net/private/org-vrO2RQa2nyCX4A3uBmZDJA6H/user-UChZNi
# zYaIqin4eVHFryXCTx/img-fSuJEsQ3zhxWwsdswSF3pvDe.png?st=2024-07-11T05%3A56%3A01Z&se=2024-07-11T07%3A56%3A01Z&sp=r&sv
# =2023-11-03&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a81
# 4-9c849652bcb3&skt=2024-07-11T02%3A18%3A02Z&ske=2024-07-12T02%3A18%3A02Z&sks=b&skv=2023-11-03&sig=RdxR6g687hwg7R4GJ
# IbqW6Exh9rwNJZE6r%2B51Viu4HA%3D'
#         )
#     ]
# )

# %%
import requests

image_url = image_response.data[0].url

# save the image to a file
image_path = Path("../../assets/minecraft_steve_learning_python_aws.png")
image_path.write_bytes(requests.get(image_url).content)
# Out:
# 1762081

# %%
image_url = image_response.data[0].url

# display the image with max width 400px
IPython.display.Image(url=image_url, width=400)
# Out:
# <img src="https://oaidalleapiprodscus.blob.core.windows.net/private/org-vrO2RQa2nyCX4A3uBmZDJA6H/user-UChZNizYaIqin4eVHFryXCTx/img-fSuJEsQ3zhxWwsdswSF3pvDe.png?st=2024-07-11T05%3A56%3A01Z&se=2024-07-11T07%3A56%3A01Z&sp=r&sv=2023-11-03&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-07-11T02%3A18%3A02Z&ske=2024-07-12T02%3A18%3A02Z&sks=b&skv=2023-11-03&sig=RdxR6g687hwg7R4GJIbqW6Exh9rwNJZE6r%2B51Viu4HA%3D" width="400"/>

# %% [markdown]
# <img src="../../assets/learning-aws-and-python.png" width="300px" />

# %% [markdown]
# ## Text to speech
#
# OpenAPI SDK docs on text to speech [here](https://platform.openai.com/docs/guides/text-to-speech).

# %%
client = AsyncOpenAI()

async with client.audio.speech.with_streaming_response.create(
    model="tts-1",
    voice="echo",
    input="""
    I wanna be the very best
    Like no one ever was
    To catch them is my real test
    To train them is my cause""",
) as response:
    await response.stream_to_file("speech.mp3")
    print(response)
# Out:
# <AsyncStreamedBinaryAPIResponse [200 OK] type=<class 'bytes'>>

# %%
IPython.display.Audio("../../assets/speech.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
client = AsyncOpenAI()

audio_response = await client.audio.speech.with_raw_response.create(
    model="tts-1",
    voice="echo",
    input="""
    I wanna be the very best
    Like no one ever was
    To catch them is my real test
    To train them is my cause""",
    response_format="wav",
)

print(audio_response)
# Out:
# <APIResponse [200 OK] type=<class 'openai._legacy_response.HttpxBinaryResponseContent'>>

# %%
IPython.display.Audio(audio_response.content)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
with open("../../assets/speech.wav", "wb") as f:
    f.write(audio_response.content)

# %%
audio_response.headers.get("Content-Type")
# Out:
# 'audio/wav'

# %%
print(audio_response.headers)
# Out:
# Headers([('date', 'Thu, 11 Jul 2024 07:03:04 GMT'), ('content-type', 'audio/wav'), ('transfer-encoding',
# 'chunked'), ('connection', 'keep-alive'), ('openai-organization', 'user-uchznizyaiqin4evhfryxctx'),
# ('openai-processing-ms', '32'), ('openai-version', '2020-10-01'), ('strict-transport-security', 'max-age=31536000;
# includeSubDomains'), ('x-ratelimit-limit-requests', '50'), ('x-ratelimit-remaining-requests', '49'),
# ('x-ratelimit-reset-requests', '1.2s'), ('x-request-id', 'req_babe58a564580ba8626cec6379356f4f'),
# ('cf-cache-status', 'DYNAMIC'), ('set-cookie',
# '__cf_bm=eZfWVP_yx7VCt1gJ2gMFsc1bL8gyS37Bgqxf89QT4RM-1720681384-1.0.1.1-28h_mkCfMXGb7hXfeQpKRgsHQ1dSJ0hABlHLP6Y6bFu
# bYfuEw55hExSm9AGfx3pdUVEHF0vrSv8R0zCf1dxr1g; path=/; expires=Thu, 11-Jul-24 07:33:04 GMT; domain=.api.openai.com;
# HttpOnly; Secure; SameSite=None'), ('set-cookie',
# '_cfuvid=E2ALe5lopS2.7JWu7aNOce6ZLrb7sIwOCnCX2smdNaQ-1720681384145-0.0.1.1-604800000; path=/;
# domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), ('server', 'cloudflare'), ('cf-ray',
# '8a16ee782c883b43-BOM'), ('alt-svc', 'h3=":443"; ma=86400')])

# %% [markdown]
# ## Mocking the Chat API using Docker and MockServer 🐳
#
# In the `mocked-openai/` folder you will find a `docker-compose.yaml` file that can simulate responses to API calls.
#
# This runs the www.mock-server.com project which can return pre-defined responses to API calls.
#
# By running `docker compose up` in the `mocked-openai/` directory, you can simulate, e.g. a `POST /chat/completions`
# request to the OpenAI API.
#
# > You can see a UI containing the requests you make to mock server here: http://localhost:1080/mockserver/dashboard
#
# <img src="../../assets/mockserver.png" width="400px">
#
# You can find the full OpenAPI spec for OpenAI [here](https://github.com/openai/openai-openapi/blob/master/openapi.yaml).
#
# ```yaml
# # docker-compose yaml
# services:
#   mockserver:
#       image: mockserver/mockserver:latest
#       ports:
#         - "1080:1080"
#       environment:
#         # MOCKSERVER_PROPERTY_FILE: /data/mockserver.properties
#         MOCKSERVER_INITIALIZATION_JSON_PATH: /data/preset-openai-responses.json
#         # ↓ hot reload when the spec.json changes 😍
#         MOCKSERVER_WATCH_INITIALIZATION_JSON: "true"
#       volumes:
#         # bind the config for easy editing
#         - .:/data
# ```
#
# Example `mockserver`
#
# ```json
# {
#     "httpRequest": {
#         "method": "POST",
#         "path": "/chat/completions"
#     },
#     "httpResponse": {
#         "statusCode": 200,
#         "headers": {
#             "Content-Type": [
#                 "application/json"
#             ]
#         },
#         "body": {
#             "id": "chatcmpl-6lX3c8j6jNfOo0zHvX56A1E7",
#             ...
#             "model": "gpt-4-0314",
#             "choices": [
#                 {
#                     "index": 0,
#                     "message": {
#                         "role": "assistant",
#                         "content": "This is a mock response from the chat completion endpoint."
#                     },
#                     "finish_reason": "stop"
#                 }
#             ],
#             ...
#         }
#     }
# }
# ```

# %%
from openai.types.chat import ChatCompletion

system_prompt = "You are an autocompletion tool that produces text files given constraints."
prompt = "toml file representing a setuptools python package"

# point to a local mock of OpenAI
client = AsyncOpenAI(base_url="http://localhost:1080", api_key="mocked_key")

response: ChatCompletion = await client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": prompt},
    ],
    max_tokens=100,  # avoid burning your credits
    n=2,  # number of responses
)

print(response)
# Out:
# ChatCompletion(
#     id='chatcmpl-6lX3c8j6jNfOo0zHvX56A1E7',
#     choices=[
#         Choice(
#             finish_reason='stop',
#             index=0,
#             logprobs=None,
#             message=ChatCompletionMessage(
#                 content='This is a mock response from the chat completion endpoint.',
#                 role='assistant',
#                 function_call=None,
#                 tool_calls=None
#             )
#         )
#     ],
#     created=1677628902,
#     model='gpt-4-0314',
#     object='chat.completion',
#     service_tier=None,
#     system_fingerprint=None,
#     usage=CompletionUsage(completion_tokens=14, prompt_tokens=9, total_tokens=23)
# )

# %%
type(response.choices[0].message.content)
# Out:
# str

# %%
# using the same mocked client
client = AsyncOpenAI(base_url="http://localhost:1080", api_key="mocked_key")


image_response = await client.images.generate(
  model="dall-e-3",
  prompt="minecraft steve learning Python and AWS",
  size="1024x1024",
  quality="standard",
  n=1,
)

print(image_response)

# display
image_url = image_response.data[0].url
IPython.display.Image(url=image_url, width=400)
# Out:
# ImagesResponse(
#     created=1677628902,
#     data=[
#         Image(
#             b64_json=None,
#             revised_prompt=None,
#             url='https://repository-images.githubusercontent.com/516708998/571919ae-d303-406d-8098-af4b2d2fb6be'
#         )
#     ],
#     id='imggen-9X3c8j6jNfOo0zHvX56A1E7',
#     object='image.generation',
#     model='dall-e-2024',
#     usage={'prompt_tokens': 15, 'completion_tokens': 1, 'total_tokens': 16}
# )
# <img src="https://repository-images.githubusercontent.com/516708998/571919ae-d303-406d-8098-af4b2d2fb6be" width="400"/>
